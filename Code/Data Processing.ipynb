# %%
import pandas as pd 
import numpy as np 
import yfinance as yf
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import roc_curve, auc
import yfinance as yf
import nltk
import seaborn as sns
sns.set_theme()
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20})

# %% [markdown]
# # **Import data**

# %%
headline_url = 'https://raw.githubusercontent.com/BrianNguyen2001/Predict-Etherium-movement-by-Machine-Learning/main/Data/headline_ETH_2017_2022.csv'
etherium_inf_url = 'https://raw.githubusercontent.com/BrianNguyen2001/Predict-Etherium-movement-by-Machine-Learning/main/Data/eth_blockchain_infomation%20.csv'

# %%
# Import data from yahoo.finance
df_btc = yf.download('BTC-USD', 
                       start='2017-11-10', 
                       end='2022-05-30',
                       progress=False)
df_btc.rename(columns={'Open': 'open', "High": 'high', "Low": 'low', "Close": 'close', 'Adj Close': 'adj_close','Volume': 'volume', }, inplace=True)

df_eth = yf.download('ETH-USD', 
                       start='2017-11-10', 
                       end='2022-05-30',
                       progress=False)
df_eth.rename(columns={'Open': 'open', "High": 'high', "Low": 'low', "Close": 'close', 'Adj Close': 'adj_close','Volume': 'volume', }, inplace=True)

df_ltc = yf.download('LTC-USD', 
                       start='2017-11-10', 
                       end='2022-05-30',
                       progress=False)
df_ltc.rename(columns={'Open': 'open', "High": 'high', "Low": 'low', "Close": 'close', 'Adj Close': 'adj_close','Volume': 'volume', }, inplace=True)

crawling_data = pd.read_csv(headline_url,index_col=0)

etherium_inf = pd.read_csv(etherium_inf_url,index_col=0)
etherium_inf.rename(columns={'Average Difficulty': 'avg_diff', "Active Addresses Count": 'act_address', "Average Transaction Fees": 'avg_gas', "Transactions Count": 'trans_count', 'Block Count': 'block_count','Block Size (bytes)': 'block_size', }, inplace=True)

# %%
etherium_inf.index = etherium_inf.index.astype('datetime64[ns]')

df_btc = df_btc.adj_close
df_btc.index = df_btc.index.astype('datetime64[ns]')

df_eth = df_eth.adj_close
df_eth.index = df_eth.index.astype('datetime64[ns]')

df_ltc = df_ltc.adj_close
df_ltc.index = df_ltc.index.astype('datetime64[ns]')

# %%
# Tạo dataframe dữ liệu để xây dựng mô hình.
data = pd.concat([df_eth,df_btc,df_ltc,etherium_inf],axis=1)
data.columns = ['price_etherium', 'price_bitcoin','price_litecoin', 'avg_diff', 'act_address', 'avg_gas', 'trans_count', 'block_count', 'block_size']
data
# Out:
#             price_etherium  price_bitcoin  price_litecoin      avg_diff  \
# Date
# 2017-11-09      320.884003    7143.580078       64.269699  1.420000e+15
# 2017-11-10      299.252991    6618.140137       59.260101  1.430000e+15
# 2017-11-11      314.681000    6357.600098       62.303299  1.440000e+15
# 2017-11-12      307.907990    5950.069824       59.005402  1.490000e+15
# 2017-11-13      316.716003    6559.490234       61.396500  1.460000e+15
# ...                    ...            ...             ...           ...
# 2022-05-25     1944.827881   29562.361328       68.313118  1.440000e+16
# 2022-05-26     1803.913330   29267.224609       63.828136  1.420000e+16
# 2022-05-27     1724.922852   28627.574219       61.563923  1.460000e+16
# 2022-05-28     1757.941772   28814.900391       62.313278  1.430000e+16
# 2022-05-29     1812.031006   29445.957031       63.746628  1.450000e+16
#
#             act_address   avg_gas  trans_count  block_count  block_size
# Date
# 2017-11-09       243554  0.222171     467172.0         6195    86289173
# 2017-11-10       233966  0.191088     457427.0         6300    84500680
# 2017-11-11       194696  0.186744     394378.0         6267    79370301
# 2017-11-12       213315  0.210592     434380.0         6245    82639583
# 2017-11-13       214384  0.220279     443176.0         6225    89907928
# ...                 ...       ...          ...          ...         ...
# 2022-05-25       508395  6.325360    1094639.0         6165   633978416
# 2022-05-26       474790  8.062978    1071180.0         6092   687245210
# 2022-05-27       494940  6.816255    1093469.0         6218   618243706
# 2022-05-28       540980  3.731229    1069802.0         6166   593458267
# 2022-05-29       525080  3.809360    1065407.0         6157   690445079
#
# [1663 rows x 9 columns]

# %%
plt.figure(figsize=(28,10))
plt.plot(data.price_etherium, color = 'coral',linewidth = 3)

plt.legend(['Price of Etherium'],fontsize=20.0)

plt.legend(['Return Etherium','SVR RBF kernel'],fontsize=20.0)
plt.xlabel('Year',fontsize = 20.0)
plt.ylabel('Price',fontsize = 20.0)
plt.xticks(fontsize = 18.0)
plt.yticks(fontsize = 18.0)

plt.title('Price of Etherium from November 2017 to May 2022',fontsize=22.0,fontweight="bold")
plt.show()

# %%
# Tính toán lợi suất của ETH, BTC and LTC
up_down = data.copy()
up_down[['price_etherium','price_bitcoin','price_litecoin']] = up_down[['price_etherium','price_bitcoin','price_litecoin']].pct_change()

up_down.columns = ['return_etherium','return_bitcoin','return_litecoin','avg_diff', 'act_address', 'avg_gas', 'trans_count', 'block_count', 'block_size']
up_down = up_down.dropna()
up_down
# Out:
#             return_etherium  return_bitcoin  return_litecoin      avg_diff  \
# Date
# 2017-11-10        -0.067411       -0.073554        -0.077946  1.430000e+15
# 2017-11-11         0.051555       -0.039368         0.051353  1.440000e+15
# 2017-11-12        -0.021523       -0.064101        -0.052933  1.490000e+15
# 2017-11-13         0.028606        0.102422         0.040523  1.460000e+15
# 2017-11-14         0.066037        0.011626         0.020899  1.450000e+15
# ...                     ...             ...              ...           ...
# 2022-05-25        -0.017259       -0.003144        -0.028561  1.440000e+16
# 2022-05-26        -0.072456       -0.009984        -0.065653  1.420000e+16
# 2022-05-27        -0.043788       -0.021856        -0.035474  1.460000e+16
# 2022-05-28         0.019142        0.006544         0.012172  1.430000e+16
# 2022-05-29         0.030769        0.021900         0.023002  1.450000e+16
#
#             act_address   avg_gas  trans_count  block_count  block_size
# Date
# 2017-11-10       233966  0.191088     457427.0         6300    84500680
# 2017-11-11       194696  0.186744     394378.0         6267    79370301
# 2017-11-12       213315  0.210592     434380.0         6245    82639583
# 2017-11-13       214384  0.220279     443176.0         6225    89907928
# 2017-11-14       226170  0.235910     475984.0         6122    99374433
# ...                 ...       ...          ...          ...         ...
# 2022-05-25       508395  6.325360    1094639.0         6165   633978416
# 2022-05-26       474790  8.062978    1071180.0         6092   687245210
# 2022-05-27       494940  6.816255    1093469.0         6218   618243706
# 2022-05-28       540980  3.731229    1069802.0         6166   593458267
# 2022-05-29       525080  3.809360    1065407.0         6157   690445079
#
# [1654 rows x 9 columns]

# %% [markdown]
# **Xử lý dữ liệu crawling**

# %%
crawling_data.index = crawling_data.index.astype('datetime64[ns]')
crawling_data.drop(['link'],axis=1,inplace=True)
crawling_data
# Out:
#                                                         title
# Time
# 2017-11-09  DreamTeam Creates the First and Largest Recrui...
# 2017-11-09  Blockchain Is a Game-Changer for Online Advert...
# 2017-11-09  Mark Cuban: Here's the best way to invest your...
# 2017-11-09  'Irrational exuberance' in ICOs but the tech i...
# 2017-11-09  Crown (CRW), The Blockchain Startup Platform, ...
# ...                                                       ...
# 2022-05-28  Ethereum’s ‘reorg’ issue and other factors led...
# 2022-05-28  Solana Just Topped Ethereum in Daily NFT Sales...
# 2022-05-28  Ethereum Founder Vitalik Buterin Defends Algo-...
# 2022-05-29  Battered DeFi Investors Put Their Hopes in Eth...
# 2022-05-29  Ethereum Whale Buys $1.5M Worth Of Shiba Inu I...
#
# [8235 rows x 1 columns]

# %% [markdown]
# **Mô tả dữ liệu headline**

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop=set(stopwords.words('english'))

corpus=[]
new= crawling_data['title'].str.split()
new=new.values.tolist()
corpus=[word for i in new for word in i]

from collections import defaultdict
dic=defaultdict(int)
for word in corpus:
    if word in stop:
        dic[word]+=1
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stop_words = pd.DataFrame(dic, index=['Count'])
stop_words = stop_words.T
stop_words = stop_words.sort_values(by='Count',ascending=False)
stop_words = stop_words[stop_words.Count >150]

courses = list(stop_words.index)
values = list(stop_words.Count)
  
fig = plt.figure(figsize = (25,10))
 
# creating the bar plot
plt.bar(courses, values, color ='maroon',
        width = 0.4)

plt.xlabel("Count",fontsize = 20.0)
plt.ylabel("Frequency stop words",fontsize = 20.0)
plt.title("Count of stop words",size = 22.0,fontweight="bold")

plt.xticks(fontsize = 18.0)
plt.yticks(fontsize = 18.0)

plt.show()

# %%
corpus_new = []
for i in corpus:
    i = i.lower()
    i = i.split(',')[0]
    if i not in stop and len(i) > 2:
        corpus_new.append(i)

import seaborn as sns
from collections import Counter
counter=Counter(corpus_new)
most=counter.most_common()

x, y= [], []
for word,count in most[:40]:
    if (word not in stop):
        x.append(word)
        y.append(count)

plt.figure(figsize=(30,20))
sns.barplot(x=y,y=x)   

plt.title('Common words frequency',size=22.0,fontweight="bold")
plt.xlabel('Count',fontsize = 20.0)
plt.ylabel('Words',fontsize = 20.0)

plt.xticks(fontsize = 18.0)
plt.yticks(fontsize = 18.0)

plt.show()

# %% [markdown]
# **Sentiments Analysis**

# %%
from textblob import TextBlob
import nltk

# %%
def polarity_and_subjectivity(df,x_input):
    list_score_polarity = []
    list_score_subjectivity = []

    for i in df.title:
        analysis = TextBlob(i).sentiment
        score_polarity = analysis[0]
        score_subjectivity = analysis[1]
        list_score_polarity.append(score_polarity)
        list_score_subjectivity.append(score_subjectivity)
    
    if x_input == 'polarity':
        return list_score_polarity
    else:
        return list_score_subjectivity

# %%
df_sent = crawling_data.copy()
df_sent['polarity'] = polarity_and_subjectivity(df_sent,'polarity')
df_sent['subjectivity'] = polarity_and_subjectivity(df_sent,'subjectivity')
df_sent
# Out:
#                                                         title  polarity  \
# Time
# 2017-11-09  DreamTeam Creates the First and Largest Recrui...  0.250000
# 2017-11-09  Blockchain Is a Game-Changer for Online Advert...  0.000000
# 2017-11-09  Mark Cuban: Here's the best way to invest your...  0.642857
# 2017-11-09  'Irrational exuberance' in ICOs but the tech i...  0.000000
# 2017-11-09  Crown (CRW), The Blockchain Startup Platform, ...  0.000000
# ...                                                       ...       ...
# 2022-05-28  Ethereum’s ‘reorg’ issue and other factors led... -0.125000
# 2022-05-28  Solana Just Topped Ethereum in Daily NFT Sales...  0.000000
# 2022-05-28  Ethereum Founder Vitalik Buterin Defends Algo-...  0.000000
# 2022-05-29  Battered DeFi Investors Put Their Hopes in Eth...  0.000000
# 2022-05-29  Ethereum Whale Buys $1.5M Worth Of Shiba Inu I...  0.300000
#
#             subjectivity
# Time
# 2017-11-09      0.333333
# 2017-11-09      0.000000
# 2017-11-09      0.417857
# 2017-11-09      0.000000
# 2017-11-09      0.000000
# ...                  ...
# 2022-05-28      0.375000
# 2022-05-28      0.000000
# 2022-05-28      0.000000
# 2022-05-29      0.000000
# 2022-05-29      0.100000
#
# [8235 rows x 3 columns]

# %%
import seaborn as sns
# plt.style.use('fivethirtyeight')

# %%
plt.figure(figsize=(25,8))
plt.hist(df_sent.polarity, color='coral', alpha = 0.9)
plt.hist(df_sent.subjectivity, color='c', alpha = 0.7)

plt.title('The polarity & subjectivity distribution',size=22.0,fontweight="bold")
plt.ylabel('Frequency',fontsize = 20.0)
plt.xlabel('Polarity & subjectivity score',fontsize = 20.0)
plt.xticks(fontsize = 18.0)
plt.yticks(fontsize = 18.0)

plt.show()

# %%
df_sent = df_sent.groupby('Time').mean()
df_sent
# Out:
#             polarity  subjectivity
# Time
# 2017-11-09  0.148810      0.125198
# 2017-11-10  0.000000      0.000000
# 2017-11-11  0.050000      0.272917
# 2017-11-12  0.000000      0.000000
# 2017-11-13  0.116667      0.308333
# ...              ...           ...
# 2022-05-25  0.200000      0.162500
# 2022-05-26  0.163997      0.277742
# 2022-05-27 -0.051562      0.317188
# 2022-05-28  0.078125      0.196875
# 2022-05-29  0.150000      0.050000
#
# [1572 rows x 2 columns]

# %% [markdown]
# **Tính toán pos, neu và neg**

# %%
 def getAnalysis(score):
  if score < 0:
    return "Negative"
  elif score == 0:
    return "Neutral"
  else:
    return "Positive"

df_sent["sentiment_analysis"] = df_sent['polarity'].apply(getAnalysis )

# %%
df_sent
# Out:
#             polarity  subjectivity sentiment_analysis
# Time
# 2017-11-09  0.148810      0.125198           Positive
# 2017-11-10  0.000000      0.000000            Neutral
# 2017-11-11  0.050000      0.272917           Positive
# 2017-11-12  0.000000      0.000000            Neutral
# 2017-11-13  0.116667      0.308333           Positive
# ...              ...           ...                ...
# 2022-05-25  0.200000      0.162500           Positive
# 2022-05-26  0.163997      0.277742           Positive
# 2022-05-27 -0.051562      0.317188           Negative
# 2022-05-28  0.078125      0.196875           Positive
# 2022-05-29  0.150000      0.050000           Positive
#
# [1572 rows x 3 columns]

# %%
dummy = pd.get_dummies(df_sent.sentiment_analysis).iloc[:,[0,2]]
score_sent = pd.concat([df_sent,dummy],axis=1)
score_sent.drop(['sentiment_analysis'],axis=1,inplace=True)
score_sent
# Out:
#             polarity  subjectivity  Negative  Positive
# Time
# 2017-11-09  0.148810      0.125198         0         1
# 2017-11-10  0.000000      0.000000         0         0
# 2017-11-11  0.050000      0.272917         0         1
# 2017-11-12  0.000000      0.000000         0         0
# 2017-11-13  0.116667      0.308333         0         1
# ...              ...           ...       ...       ...
# 2022-05-25  0.200000      0.162500         0         1
# 2022-05-26  0.163997      0.277742         0         1
# 2022-05-27 -0.051562      0.317188         1         0
# 2022-05-28  0.078125      0.196875         0         1
# 2022-05-29  0.150000      0.050000         0         1
#
# [1572 rows x 4 columns]

# %%
df_finish = pd.concat([score_sent,up_down],axis=1)
df_finish = df_finish[df_finish.return_etherium.notna()]
df_finish
# Out:
#             polarity  subjectivity  Negative  Positive  return_etherium  \
# 2017-11-10  0.000000      0.000000       0.0       0.0        -0.067411
# 2017-11-11  0.050000      0.272917       0.0       1.0         0.051555
# 2017-11-12  0.000000      0.000000       0.0       0.0        -0.021523
# 2017-11-13  0.116667      0.308333       0.0       1.0         0.028606
# 2017-11-14  0.000000      0.000000       0.0       0.0         0.066037
# ...              ...           ...       ...       ...              ...
# 2022-05-25  0.200000      0.162500       0.0       1.0        -0.017259
# 2022-05-26  0.163997      0.277742       0.0       1.0        -0.072456
# 2022-05-27 -0.051562      0.317188       1.0       0.0        -0.043788
# 2022-05-28  0.078125      0.196875       0.0       1.0         0.019142
# 2022-05-29  0.150000      0.050000       0.0       1.0         0.030769
#
#             return_bitcoin  return_litecoin      avg_diff  act_address  \
# 2017-11-10       -0.073554        -0.077946  1.430000e+15     233966.0
# 2017-11-11       -0.039368         0.051353  1.440000e+15     194696.0
# 2017-11-12       -0.064101        -0.052933  1.490000e+15     213315.0
# 2017-11-13        0.102422         0.040523  1.460000e+15     214384.0
# 2017-11-14        0.011626         0.020899  1.450000e+15     226170.0
# ...                    ...              ...           ...          ...
# 2022-05-25       -0.003144        -0.028561  1.440000e+16     508395.0
# 2022-05-26       -0.009984        -0.065653  1.420000e+16     474790.0
# 2022-05-27       -0.021856        -0.035474  1.460000e+16     494940.0
# 2022-05-28        0.006544         0.012172  1.430000e+16     540980.0
# 2022-05-29        0.021900         0.023002  1.450000e+16     525080.0
#
#              avg_gas  trans_count  block_count   block_size
# 2017-11-10  0.191088     457427.0       6300.0   84500680.0
# 2017-11-11  0.186744     394378.0       6267.0   79370301.0
# 2017-11-12  0.210592     434380.0       6245.0   82639583.0
# 2017-11-13  0.220279     443176.0       6225.0   89907928.0
# 2017-11-14  0.235910     475984.0       6122.0   99374433.0
# ...              ...          ...          ...          ...
# 2022-05-25  6.325360    1094639.0       6165.0  633978416.0
# 2022-05-26  8.062978    1071180.0       6092.0  687245210.0
# 2022-05-27  6.816255    1093469.0       6218.0  618243706.0
# 2022-05-28  3.731229    1069802.0       6166.0  593458267.0
# 2022-05-29  3.809360    1065407.0       6157.0  690445079.0
#
# [1654 rows x 13 columns]

# %%
df_finish.isna().sum()
# Out:
# polarity           91
# subjectivity       91
# Negative           91
# Positive           91
# return_etherium     0
# return_bitcoin      0
# return_litecoin     0
# avg_diff            0
# act_address         0
# avg_gas             0
# trans_count         0
# block_count         0
# block_size          0
# dtype: int64

# %%
df_finish.fillna(method='ffill',inplace=True)
df_finish.isna().sum()
# Out:
# polarity           0
# subjectivity       0
# Negative           0
# Positive           0
# return_etherium    0
# return_bitcoin     0
# return_litecoin    0
# avg_diff           0
# act_address        0
# avg_gas            0
# trans_count        0
# block_count        0
# block_size         0
# dtype: int64

# %%
df_finish.index = df_finish.index.set_names('Time')

# %%
# df_finish.to_csv('pred_eth_data.csv')
